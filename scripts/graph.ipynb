# %%
from google.colab import drive, runtime
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image

# %% [markdown]
# # epochs -> 60

# %% [markdown]
# ## 1e-4 / 0.1
#
# 배치 8,16,32 순으로 mAP50-95 그래프의 흔들리는 게 점점 줄어든다.
#
# 확실히 32 배치가 전체 데이터셋의 평균적인 데이터를 반영하므로 보다 안정성이 좋다는것이 보인다.
#
# 하지만, 32,16,8 배치가 mAP50-95의 수치에 영향은 주지 못했다. 비슷한 수치 결과가 나온다.

# %% [markdown]
# ### batch -> 8(0.865      0.854)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.1_batch_8/train2/results.png', width=1000)

# %% [markdown]
# ### batch -> 16(0.861      0.855)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.1_batch_16/train2/results.png', width=1000)

# %% [markdown]
# ### batch -> 32(0.862      0.855)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.1_batch_32/train2/results.png', width=1000)

# %% [markdown]
# ## 1e-4 / lrf 0.01
#
# lrf 0.1과 다른점이라고 하면 batch 8의 mAP가 올랐다는점이다.
# 하지만 batch 16, 32는 mAP가 다르지 않다.

# %% [markdown]
# ### batch -> 8(0.87       0.86)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.01_batch_8/train2/results.png', width=1000)

# %% [markdown]
# ### batch -> 16(0.856      0.851)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.01_batch_16/train2/results.png', width=1000)

# %% [markdown]
# ### batch -> 32( 0.859      0.852)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.01_batch_32/train2/results.png', width=1000)

# %% [markdown]
# ## 1e-5 / 0.1

# %% [markdown]
# ### batch 8(0.869      0.863)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_1e-05_lrf_0.1_batch_8/train2/results.png', width=1000)

# %% [markdown]
# ### batch 16(0.861      0.855)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.01_batch_16/train2/results.png', width=1000)

# %% [markdown]
# ### batch 32(0.862      0.855)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/grid_search/lr0_0.0001_lrf_0.01_batch_32/train2/results.png', width=1000)

# %% [markdown]
# # YOLO Genetic Algorithm

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/tune/tune_fitness.png', width=1000)

# %%
Image(filename=f'/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/tune/tune_scatter_plots.png', width=1000)

# %% [markdown]
# # Best hyp model
#     epochs: 60
#     imgsz: 640
#     seed: 42
#     multi_scale: True
#     close_mosaic: 10
#     batch= 16,
#     lr0= 0.00076,
#     lrf= 0.001,
#     hsv_h= 0.21309,
#     hsv_s= 0.64489,
#     hsv_v= 0.47858,

# %%
Image(filename='/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/tune2/tune_fitness.png', width=1000)

# %%
Image(filename='/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/tune2/tune_scatter_plots.png', width=1000)

# %%
Image(filename='/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/train504/results.png',width=1000)

# %%
Image(filename='/content/drive/Othercomputers/내 MacBook Air/Documents/ai_project/beginner_project/checkpoints/train504/labels_correlogram.jpg', width=1000)
